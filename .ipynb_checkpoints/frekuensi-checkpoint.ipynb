# %%
import os
import string
from docx import Document
from nltk.corpus import stopwords
from nltk.probability import FreqDist
from nltk.tokenize import word_tokenize
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# Fungsi untuk membaca teks dari berkas DOCX
def read_text_from_docx(file_path):
    doc = Document(file_path)
    text = ""
    for paragraph in doc.paragraphs:
        text += paragraph.text + "\n"
    return text

def remove_suffixes_and_non_alnum(word):
    return ''.join(e for e in word if e.isalnum())

def stem_text(tokens):
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
    stemmed_tokens = [stemmer.stem(token) for token in tokens]
    return stemmed_tokens

def preprocess_text(text):
    text = text.lower()
    text = text.translate(str.maketrans('', '', string.punctuation))
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words('indonesian'))
    filtered_tokens = [token for token in tokens if token not in stop_words]
    
    stemmed_tokens = stem_text(filtered_tokens)
    preprocessed_tokens = [remove_suffixes_and_non_alnum(token) for token in stemmed_tokens if token]
    return ' '.join(preprocessed_tokens)

def tokenize_text(text):
    tokens = word_tokenize(text)
    return [token for token in tokens if token.isalnum()]

def calculate_word_frequency(tokens):
    fdist = FreqDist(tokens)
    return fdist


absen = input("Berapa Absenmu: ")

# Absen yang akan diinput
target_absen = f"33226000{absen}"

# Direktori utama (folder "Berita")
base_directory = '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source'
hasil_directory = '/Users/farrelmanazilin/Downloads/data/Text Mining/Hasil'

# Daftar folder yang ingin diperiksa
folders_to_check = ['Kesehatan', 'Teknologi', 'Politik', 'Olahraga', 'Kriminal']

# Loop melalui setiap folder
for folder_name in folders_to_check:
    folder_path = os.path.join(base_directory, folder_name)
    hasil_path = os.path.join(hasil_directory, folder_name)

    # Loop melalui setiap file dalam folder
    for filename in os.listdir(folder_path):
        if target_absen in filename:
            # Construct the target file name with the folder name
            output_file_name = f'frekuensi_kata_{filename.replace(".docx", "")}.txt'  # Hapus ekstensi .docx

            # File dengan nama yang mirip ditemukan dalam folder ini
            file_path = os.path.join(folder_path, filename)
            print(f"File dengan nama yang mirip ditemukan di folder '{folder_name}': {file_path}")

            # Baca teks dari file DOCX dan proses
            text = read_text_from_docx(file_path)
            preprocessed_text = preprocess_text(text)
            tokens = tokenize_text(preprocessed_text)
            word_frequency = calculate_word_frequency(tokens)

            # Pastikan direktori output sudah ada atau buat jika belum ada
            if not os.path.exists(hasil_path):
                os.makedirs(hasil_path)

            # Menyimpan hasil frekuensi kata-kata ke dalam berkas teks (txt)
            output_file_path = os.path.join(hasil_path, output_file_name)  # Perbarui output_file_path
            with open(output_file_path, 'w') as file:
                file.write('Kata\t\t\tFrekuensi\n')  # Header

                # Isi file dengan data frekuensi kata-kata
                for word, freq in word_frequency.items():
                    file.write(f'{word}\t\t\t{freq}\n')

            print(f"Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '{output_file_path}'.\n")

print("Selesai")
# Out:
# Berapa Absenmu: 11
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Downloads/data/Text Mining/Berita/Kesehatan/Kesehatan_3322600011_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Downloads/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600011_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Downloads/data/Text Mining/Berita/Kesehatan/Kesehatan_3322600011_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Downloads/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600011_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Downloads/data/Text Mining/Berita/Kesehatan/Kesehatan_3322600011_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Downloads/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600011_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Downloads/data/Text Mining/Berita/Kesehatan/Kesehatan_3322600011_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Downloads/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600011_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Downloads/data/Text Mining/Berita/Kesehatan/Kesehatan_3322600011_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Downloads/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600011_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Teknologi': /Users/farrelmanazilin/Downloads/data/Text Mining/Berita/Teknologi/Teknologi_3322600011_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Downloads/data/Text Mining/Hasil/Teknologi/frekuensi_kata_Teknologi_3322600011_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Teknologi': /Users/farrelmanazilin/Downloads/data/Text Mining/Berita/Teknologi/Teknologi_3322600011_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Downloads/data/Text Mining/Hasil/Teknologi/frekuensi_kata_Teknologi_3322600011_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Teknologi': /Users/farrelmanazilin/Downloads/data/Text Mining/Berita/Teknologi/Teknologi_3322600011_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Downloads/data/Text Mining/Hasil/Teknologi/frekuensi_kata_Teknologi_3322600011_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Teknologi': /Users/farrelmanazilin/Downloads/data/Text Mining/Berita/Teknologi/Teknologi_3322600011_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Downloads/data/Text Mining/Hasil/Teknologi/frekuensi_kata_Teknologi_3322600011_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Teknologi': /Users/farrelmanazilin/Downloads/data/Text Mining/Berita/Teknologi/Teknologi_3322600011_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Downloads/data/Text Mining/Hasil/Teknologi/frekuensi_kata_Teknologi_3322600011_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Politik': /Users/farrelmanazilin/Downloads/data/Text Mining/Berita/Politik/Politik_3322600011_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Downloads/data/Text Mining/Hasil/Politik/frekuensi_kata_Politik_3322600011_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Politik': /Users/farrelmanazilin/Downloads/data/Text Mining/Berita/Politik/Politik_3322600011_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Downloads/data/Text Mining/Hasil/Politik/frekuensi_kata_Politik_3322600011_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Politik': /Users/farrelmanazilin/Downloads/data/Text Mining/Berita/Politik/Politik_3322600011_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Downloads/data/Text Mining/Hasil/Politik/frekuensi_kata_Politik_3322600011_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Politik': /Users/farrelmanazilin/Downloads/data/Text Mining/Berita/Politik/Politik_3322600011_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Downloads/data/Text Mining/Hasil/Politik/frekuensi_kata_Politik_3322600011_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Politik': /Users/farrelmanazilin/Downloads/data/Text Mining/Berita/Politik/Politik_3322600011_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Downloads/data/Text Mining/Hasil/Politik/frekuensi_kata_Politik_3322600011_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Olahraga': /Users/farrelmanazilin/Downloads/data/Text Mining/Berita/Olahraga/Olahraga_3322600011_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Downloads/data/Text Mining/Hasil/Olahraga/frekuensi_kata_Olahraga_3322600011_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Olahraga': /Users/farrelmanazilin/Downloads/data/Text Mining/Berita/Olahraga/Olahraga_3322600011_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Downloads/data/Text Mining/Hasil/Olahraga/frekuensi_kata_Olahraga_3322600011_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Olahraga': /Users/farrelmanazilin/Downloads/data/Text Mining/Berita/Olahraga/Olahraga_3322600011_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Downloads/data/Text Mining/Hasil/Olahraga/frekuensi_kata_Olahraga_3322600011_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Olahraga': /Users/farrelmanazilin/Downloads/data/Text Mining/Berita/Olahraga/Olahraga_3322600011_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Downloads/data/Text Mining/Hasil/Olahraga/frekuensi_kata_Olahraga_3322600011_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Olahraga': /Users/farrelmanazilin/Downloads/data/Text Mining/Berita/Olahraga/Olahraga_3322600011_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Downloads/data/Text Mining/Hasil/Olahraga/frekuensi_kata_Olahraga_3322600011_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Downloads/data/Text Mining/Berita/Kriminal/Kriminal_3322600011_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Downloads/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600011_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Downloads/data/Text Mining/Berita/Kriminal/Kriminal_3322600011_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Downloads/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600011_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Downloads/data/Text Mining/Berita/Kriminal/Kriminal_3322600011_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Downloads/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600011_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Downloads/data/Text Mining/Berita/Kriminal/Kriminal_3322600011_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Downloads/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600011_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Downloads/data/Text Mining/Berita/Kriminal/Kriminal_3322600011_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Downloads/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600011_1.txt'.
#
# Selesai

# %%
import os
import string
from docx import Document
from nltk.corpus import stopwords
from nltk.probability import FreqDist
from nltk.tokenize import word_tokenize
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

def read_text_from_docx(file_path):
    doc = Document(file_path)
    text = ""
    for paragraph in doc.paragraphs:
        text += paragraph.text + "\n"
    return text

def remove_suffixes_and_non_alnum(word):
    return ''.join(e for e in word if e.isalnum())

def stem_text(tokens):
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
    stemmed_tokens = [stemmer.stem(token) for token in tokens]
    return stemmed_tokens

def preprocess_text(text):
    text = text.lower()
    text = text.translate(str.maketrans('', '', string.punctuation))
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words('indonesian'))
    filtered_tokens = [token for token in tokens if token not in stop_words]
    
    stemmed_tokens = stem_text(filtered_tokens)
    preprocessed_tokens = [remove_suffixes_and_non_alnum(token) for token in stemmed_tokens if token]
    return ' '.join(preprocessed_tokens)

def tokenize_text(text):
    tokens = word_tokenize(text)
    return [token for token in tokens if token.isalnum()]

def calculate_word_frequency(tokens):
    fdist = FreqDist(tokens)
    return fdist

base_directory = '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source'
hasil_directory = '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil'

folders_to_check = ['Kesehatan', 'Teknologi', 'Politik', 'Olahraga', 'Kriminal']

for folder_name in folders_to_check:
    folder_path = os.path.join(base_directory, folder_name)
    hasil_path = os.path.join(hasil_directory, folder_name)

    for filename in os.listdir(folder_path):
            output_file_name = f'frekuensi_kata_{filename.replace(".docx", "")}.txt'  #
            file_path = os.path.join(folder_path, filename)
            print(f"File dengan nama yang mirip ditemukan di folder '{folder_name}': {file_path}")
            text = read_text_from_docx(file_path)
            preprocessed_text = preprocess_text(text)
            tokens = tokenize_text(preprocessed_text)
            word_frequency = calculate_word_frequency(tokens)

            if not os.path.exists(hasil_path):
                os.makedirs(hasil_path)

            output_file_path = os.path.join(hasil_path, output_file_name)  
            with open(output_file_path, 'w') as file:
                file.write('Kata Frekuensi\n') 
                for word, freq in word_frequency.items():
                    file.write(f'{word} {freq}\n')

            print(f"Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '{output_file_path}'.\n")

print("Selesai")
# Out:
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600005_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600005_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600023_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600023_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600001_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600001_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/kesehatan_3322600027_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_kesehatan_3322600027_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600017_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600017_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600022_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600022_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/kesehatan_3322600009_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_kesehatan_3322600009_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600013_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600013_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600014_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600014_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600025_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600025_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600003_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600003_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/kesehatan_3322600019_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_kesehatan_3322600019_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600015_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600015_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600006_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600006_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600018_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600018_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600011_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600011_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600011_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600011_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600015_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600015_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600020_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600020_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600003_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600003_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/kesehatan_3322600019_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_kesehatan_3322600019_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600025_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600025_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/kesehatan_3322600009_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_kesehatan_3322600009_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600013_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600013_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600004_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600004_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600017_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600017_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/kesehatan_3322600027_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_kesehatan_3322600027_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600001_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600001_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600023_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600023_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600016_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600016_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600005_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600005_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600005_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600005_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600023_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600023_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600012_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600012_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600001_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600001_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/kesehatan_3322600027_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_kesehatan_3322600027_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600017_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600017_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/kesehatan_3322600009_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_kesehatan_3322600009_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600013_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600013_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600028_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600028_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600025_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600025_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600003_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600003_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/kesehatan_3322600019_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_kesehatan_3322600019_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600015_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600015_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600011_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600011_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600011_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600011_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600002_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600002_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600015_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600015_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600003_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600003_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/kesehatan_3322600019_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_kesehatan_3322600019_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600010_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600010_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600025_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600025_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/kesehatan_3322600009_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_kesehatan_3322600009_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600013_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600013_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600017_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600017_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/kesehatan_3322600027_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_kesehatan_3322600027_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600001_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600001_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600023_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600023_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600005_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600005_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600002_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600002_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600018_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600018_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600006_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600006_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600015_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600015_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600020_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600020_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600010_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600010_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/kesehatan_3322600019_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_kesehatan_3322600019_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600014_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600014_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600028_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600028_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600022_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600022_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600004_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600004_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600012_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600012_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600023_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600023_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600016_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600016_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600005_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600005_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600016_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600016_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600012_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600012_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600017_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600017_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600004_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600004_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600022_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600022_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/kesehatan_3322600009_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_kesehatan_3322600009_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600028_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600028_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600014_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600014_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600010_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600010_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600020_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600020_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600006_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600006_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600002_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600002_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600018_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600018_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600002_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600002_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600018_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600018_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600006_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600006_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600020_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600020_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600010_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600010_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600025_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600025_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600014_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600014_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600028_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600028_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600013_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600013_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600022_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600022_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600004_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600004_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600001_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600001_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600012_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600012_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600016_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600016_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600016_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600016_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600012_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600012_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/kesehatan_3322600027_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_kesehatan_3322600027_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600004_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600004_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600022_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600022_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600028_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600028_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600014_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600014_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600010_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600010_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600003_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600003_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600020_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600020_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600006_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600006_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600002_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600002_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600011_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600011_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kesehatan': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kesehatan/Kesehatan_3322600018_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kesehatan/frekuensi_kata_Kesehatan_3322600018_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Teknologi': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Teknologi/Teknologi_3322600004_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Teknologi/frekuensi_kata_Teknologi_3322600004_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Teknologi': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Teknologi/Teknologi_3322600017_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Teknologi/frekuensi_kata_Teknologi_3322600017_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Teknologi': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Teknologi/teknologi_3322600009_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Teknologi/frekuensi_kata_teknologi_3322600009_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Teknologi': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Teknologi/Teknologi_3322600013_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Teknologi/frekuensi_kata_Teknologi_3322600013_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Teknologi': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Teknologi/Teknologi_3322600023_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Teknologi/frekuensi_kata_Teknologi_3322600023_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Teknologi': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Teknologi/Teknologi_3322600016_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Teknologi/frekuensi_kata_Teknologi_3322600016_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Teknologi': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Teknologi/Teknologi_3322600005_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Teknologi/frekuensi_kata_Teknologi_3322600005_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Teknologi': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Teknologi/teknologi_3322600027_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Teknologi/frekuensi_kata_teknologi_3322600027_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Teknologi': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Teknologi/Teknologi_3322600001_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Teknologi/frekuensi_kata_Teknologi_3322600001_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Teknologi': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Teknologi/Teknologi_3322600015_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Teknologi/frekuensi_kata_Teknologi_3322600015_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Teknologi': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Teknologi/Teknologi_3322600020_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Teknologi/frekuensi_kata_Teknologi_3322600020_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Teknologi': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Teknologi/Teknologi_3322600011_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Teknologi/frekuensi_kata_Teknologi_3322600011_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Teknologi': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Teknologi/Teknologi_3322600003_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Teknologi/frekuensi_kata_Teknologi_3322600003_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Teknologi': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Teknologi/teknologi_3322600019_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Teknologi/frekuensi_kata_teknologi_3322600019_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Teknologi': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Teknologi/Teknologi_3322600025_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Teknologi/frekuensi_kata_Teknologi_3322600025_2.txt'.
#
# ...
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600028_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600014_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600014_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600014_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600014_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600028_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600028_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600010_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600010_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/kriminal_3322600006_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_kriminal_3322600006_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600020_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600020_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600018_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600018_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600002_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600002_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600016_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600016_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600005_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600005_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600012_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600012_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600022_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600022_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600004_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600004_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600017_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600017_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/kriminal_3322600009_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_kriminal_3322600009_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600013_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600013_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600004_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600004_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600022_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600022_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600012_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600012_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600001_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600001_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600016_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600016_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600018_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600018_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600002_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600002_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600020_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600020_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/kriminal_3322600006_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_kriminal_3322600006_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600025_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600025_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600010_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600010_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600028_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600028_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600014_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600014_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600014_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600014_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600028_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600028_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600003_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600003_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600010_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600010_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/kriminal_3322600006_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_kriminal_3322600006_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600020_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600020_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600011_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600011_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600018_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600018_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600002_5.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600002_5.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600016_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600016_3.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/kriminal_3322600027_1.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_kriminal_3322600027_1.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600012_4.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600012_4.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600022_2.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600022_2.txt'.
#
# File dengan nama yang mirip ditemukan di folder 'Kriminal': /Users/farrelmanazilin/Document/kuliah/data/Text Mining/Source/Kriminal/Kriminal_3322600004_3.docx
# Hasil frekuensi kata-kata setelah stemming dan preprocessing telah disimpan dalam berkas '/Users/farrelmanazilin/Document/kuliah/data/Text Mining/Hasil/Kriminal/frekuensi_kata_Kriminal_3322600004_3.txt'.
#
# Selesai
